# %%
import pandas as pd

# %%
unemploy = pd.read_csv("clean_unemployment.csv")
unemploy.head()
# Out:
#   country_code          country_name      continent   2010   2011   2012  \
# 0          AFG           Afghanistan           Asia  11.35  11.05  11.34
# 1          AGO                Angola         Africa   9.43   7.36   7.35
# 2          ALB               Albania         Europe  14.09  13.48  13.38
# 3          ARE  United Arab Emirates           Asia   2.48   2.30   2.18
# 4          ARG             Argentina  South America   7.71   7.18   7.22
#
#     2013   2014   2015   2016   2017   2018   2019   2020   2021
# 0  11.19  11.14  11.13  11.16  11.18  11.15  11.22  11.71  13.28
# 1   7.37   7.37   7.39   7.41   7.41   7.42   7.42   8.33   8.53
# 2  15.87  18.05  17.19  15.42  13.62  12.30  11.47  13.33  11.82
# 3   2.04   1.91   1.77   1.64   2.46   2.35   2.23   3.19   3.36
# 4   7.10   7.27   7.52   8.11   8.35   9.22   9.84  11.46  10.90

# %%
# to read data reagarding non missing values
unemploy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_code  182 non-null    object
#  1   country_name  182 non-null    object
#  2   continent     177 non-null    object
#  3   2010          182 non-null    float64
#  4   2011          182 non-null    float64
#  5   2012          182 non-null    float64
#  6   2013          182 non-null    float64
#  7   2014          182 non-null    float64
#  8   2015          182 non-null    float64
#  9   2016          182 non-null    float64
#  10  2017          182 non-null    float64
#  11  2018          182 non-null    float64
#  12  2019          182 non-null    float64
#  13  2020          182 non-null    float64
#  14  2021          182 non-null    float64
# dtypes: float64(12), object(3)
# memory usage: 21.5+ KB

# %%
# counting Categorical Values
unemploy.value_counts("continent")
# Out:
# continent
# Africa           53
# Asia             47
# Europe           39
# North America    18
# South America    12
# Oceania           8
# Name: count, dtype: int64

# %%
# !pip install matplotlib

# %%
# importing modules
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# Create a histogram of 2021 unemployment; show a full percent in each bin
sns.histplot(data=unemploy , x="2021" , binwidth = 1)
plt.show()

# %%
# changing data type
unemploy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_code  182 non-null    object
#  1   country_name  182 non-null    object
#  2   continent     177 non-null    object
#  3   2010          182 non-null    float64
#  4   2011          182 non-null    float64
#  5   2012          182 non-null    float64
#  6   2013          182 non-null    float64
#  7   2014          182 non-null    float64
#  8   2015          182 non-null    float64
#  9   2016          182 non-null    float64
#  10  2017          182 non-null    float64
#  11  2018          182 non-null    float64
#  12  2019          182 non-null    float64
#  13  2020          182 non-null    float64
#  14  2021          182 non-null    float64
# dtypes: float64(12), object(3)
# memory usage: 21.5+ KB

# %%
unemploy["2019"] = unemploy["2019"].astype(int)

# %%
# dtype changed
unemploy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_code  182 non-null    object
#  1   country_name  182 non-null    object
#  2   continent     177 non-null    object
#  3   2010          182 non-null    float64
#  4   2011          182 non-null    float64
#  5   2012          182 non-null    float64
#  6   2013          182 non-null    float64
#  7   2014          182 non-null    float64
#  8   2015          182 non-null    float64
#  9   2016          182 non-null    float64
#  10  2017          182 non-null    float64
#  11  2018          182 non-null    float64
#  12  2019          182 non-null    int64
#  13  2020          182 non-null    float64
#  14  2021          182 non-null    float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 21.5+ KB

# %%
# rechanged
unemploy["2019"] = unemploy["2019"].astype(float)

# %%
unemploy.dtypes
# Out:
# country_code     object
# country_name     object
# continent        object
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# 2020            float64
# 2021            float64
# dtype: object

# %%
# Define a Series describing whether each continent is outside of Oceania
not_oceania = ~unemploy["continent"].isin(["Oceania"])

# %%
# Print unemployment without records related to countries in Oceania using Boolean
print(unemploy[unemploy["continent"] !="Oceania"])
# Out:
#     country_code          country_name      continent   2010   2011   2012  \
# 0            AFG           Afghanistan           Asia  11.35  11.05  11.34
# 1            AGO                Angola         Africa   9.43   7.36   7.35
# 2            ALB               Albania         Europe  14.09  13.48  13.38
# 3            ARE  United Arab Emirates           Asia   2.48   2.30   2.18
# 4            ARG             Argentina  South America   7.71   7.18   7.22
# ..           ...                   ...            ...    ...    ...    ...
# 175          VNM               Vietnam           Asia   1.11   1.00   1.03
# 178          YEM           Yemen, Rep.           Asia  12.83  13.23  13.17
# 179          ZAF          South Africa         Africa  24.68  24.64  24.73
# 180          ZMB                Zambia         Africa  13.19  10.55   7.85
# 181          ZWE              Zimbabwe         Africa   5.21   5.37   5.15
#
#       2013   2014   2015   2016   2017   2018   2019   2020   2021
# ...

# %%
# Print the minimum and maximum unemployment rates during 2021
unemploy["2021"].min(),unemploy["2021"].max()
# Out:
# (np.float64(0.26), np.float64(33.56))

# %%
# Create a boxplot of 2021 unemployment rates, broken down by continent
sns.boxplot(data=unemploy , x="2021" , y="continent")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# create a coloumn list of year and created a new df
year = unemploy.iloc[:, 3:]

# %%
unemploy.head(5)
# Out:
#   country_code          country_name      continent   2010   2011   2012  \
# 0          AFG           Afghanistan           Asia  11.35  11.05  11.34
# 1          AGO                Angola         Africa   9.43   7.36   7.35
# 2          ALB               Albania         Europe  14.09  13.48  13.38
# 3          ARE  United Arab Emirates           Asia   2.48   2.30   2.18
# 4          ARG             Argentina  South America   7.71   7.18   7.22
#
#     2013   2014   2015   2016   2017   2018   2019   2020   2021
# 0  11.19  11.14  11.13  11.16  11.18  11.15  11.22  11.71  13.28
# 1   7.37   7.37   7.39   7.41   7.41   7.42   7.42   8.33   8.53
# 2  15.87  18.05  17.19  15.42  13.62  12.30  11.47  13.33  11.82
# 3   2.04   1.91   1.77   1.64   2.46   2.35   2.23   3.19   3.36
# 4   7.10   7.27   7.52   8.11   8.35   9.22   9.84  11.46  10.90

# %%
# Print the mean and standard deviation (in that order) of the unemployment rates for each year, grouped by continent
# 1 First Group then pass Agg function
# numeric_only = true paramenter was the issue
Groupby_df=unemploy.groupby("continent")
Groupby_df.mean(numeric_only = True)
# Out:
#                     2010       2011       2012       2013       2014  \
# continent
# Africa          9.343585   9.369245   9.240755   9.132453   9.121321
# Asia            6.240638   5.942128   5.835319   5.852128   5.853191
# Europe         11.008205  10.947949  11.325641  11.466667  10.971282
# North America   8.663333   8.563333   8.448889   8.840556   8.512222
# Oceania         3.622500   3.647500   4.103750   3.980000   3.976250
# South America   6.870833   6.518333   6.410833   6.335000   6.347500
#
#                     2015      2016      2017      2018      2019       2020  \
# continent
# Africa          9.222075  9.277547  9.284528  9.237925  9.264340  10.307736
# Asia            5.967447  6.094894  6.171277  6.090213  5.949149   7.012340
# Europe         10.301282  9.394615  8.359744  7.427436  6.764359   7.470513
# North America   8.098889  7.941111  7.391111  7.281111  7.095000   9.297778
# Oceania         3.985000  3.877500  3.872500  3.851250  3.773750   4.273750
# ...

# %%
year.head(5)
# Out:
#     2010   2011   2012   2013   2014   2015   2016   2017   2018   2019  \
# 0  11.35  11.05  11.34  11.19  11.14  11.13  11.16  11.18  11.15  11.22
# 1   9.43   7.36   7.35   7.37   7.37   7.39   7.41   7.41   7.42   7.42
# 2  14.09  13.48  13.38  15.87  18.05  17.19  15.42  13.62  12.30  11.47
# 3   2.48   2.30   2.18   2.04   1.91   1.77   1.64   2.46   2.35   2.23
# 4   7.71   7.18   7.22   7.10   7.27   7.52   8.11   8.35   9.22   9.84
#
#     2020   2021
# 0  11.71  13.28
# 1   8.33   8.53
# 2  13.33  11.82
# 3   3.19   3.36
# 4  11.46  10.90

# %%
# finding null values
print(unemploy.isnull().sum())
# Out:
# country_code    0
# country_name    0
# continent       5
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64

# %%
# converting empty space to unknown
unemploy['continent'] = unemploy['continent'].fillna('Unknown')

# %%
continent_summary = unemploy.groupby("continent").agg(
    mean_rate_2021=("2021", "mean"),
    std_rate_2021=("2021", "std")
)

# %%
continent_summary
# Out:
#                mean_rate_2021  std_rate_2021
# continent
# Africa              10.473585       8.131636
# Asia                 6.906170       5.414745
# Europe               7.414872       3.947825
# North America        9.155000       5.076482
# Oceania              4.280000       2.671522
# South America        9.924167       3.611624

# %%
# Create a bar plot of continents and their average unemployment , change color and Fit layout
unemploy.head(5)
sns.barplot(data=unemploy, x="continent" , y="2021" )
plt.setp(plt.gca().get_xticklabels(), color="blue")
plt.tight_layout()
plt.show()
